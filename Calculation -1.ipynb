# %%
from alpha_vantage.fundamentaldata import FundamentalData
Key= 'CXSKPS11U4UYHKYI'
symbol = input( 'Ticker : ')
period= input('Period- annual, quarterly: ')
statement = input('Statement- balance sheet, income statement, cash flow : ')
fd = FundamentalData(Key, output_format = 'pandas')
import pandas as pd

# %%
ticker = ['ALB']  # ticker

# income statement of the company |
IS1 = fd.get_income_statement_annual(ticker)
IS = IS1[0].T[2:]
IS.columns = list(IS1[0].T.iloc[0])
IS
# Out:
#                                    2022-12-31  2021-12-31  2020-12-31  \
# grossProfit                        3074587000   997971000   994853000
# totalRevenue                       7320104000  3327957000  3128909000
# costOfRevenue                      4245517000  2329986000  2134056000
# costofGoodsAndServicesSold         4245517000  2329986000  2134056000
# operatingIncome                    2470061000   798434000   505812000
# sellingGeneralAndAdministrative     524145000   441482000   429827000
# researchAndDevelopment               71981000    54026000    59214000
# operatingExpenses                   650865000   230576000   536676000
# investmentIncomeNet                      None        None        None
# netInterestIncome                   -34604000   -53010000   -33081000
# interestIncome                      122973000    61476000    68316000
# interestExpense                      34604000    53010000    33081000
# nonInterestIncome                   -49419000   267116000   -28800000
# otherNonOperatingIncome              86356000  -603340000   -59177000
# depreciation                        273000000   225600000   203600000
# depreciationAndAmortization          28084000    25914000    25507000
# incomeBeforeTax                    3080404000   153118000   430189000
# incomeTaxExpense                    390588000    29446000    54425000
# interestAndDebtExpense              122973000    61476000    73116000
# netIncomeFromContinuingOperations  2689816000   123672000   375764000
# comprehensiveIncomeNetOfTax        2521604000    57354000   445367000
# ebit                               2470061000   798434000   505812000
# ebitda                             3143092000   232042000   488777000
# netIncome                          2689816000   123672000   375764000
#
#                                    2019-12-31  2018-12-31
# grossProfit                        1257778000  1217256000
# totalRevenue                       3589427000  3374950000
# costOfRevenue                      2331649000  2157694000
# costofGoodsAndServicesSold         2331649000  2157694000
# operatingIncome                     666123000   911540000
# sellingGeneralAndAdministrative     533368000   446090000
# researchAndDevelopment               58287000    70054000
# operatingExpenses                   627314000   335195000
# investmentIncomeNet                      None        None
# netInterestIncome                   -30317000   -19300000
# interestIncome                       78660000    72256000
# interestExpense                      30317000    19300000
# nonInterestIncome                   -32229000   199928000
# otherNonOperatingIncome             -45478000   -64434000
# depreciation                        183300000   170000000
# depreciationAndAmortization          27747000    27979000
# incomeBeforeTax                     621389000   838388000
# incomeTaxExpense                     88161000   144826000
# interestAndDebtExpense               57695000    52405000
# netIncomeFromContinuingOperations   533228000   693562000
# comprehensiveIncomeNetOfTax         488175000   568548000
# ebit                                666123000   911540000
# ebitda                              679453000   885667000
# netIncome                           533228000   693562000

# %%
#BALANCE SHEET OF THE COMPANY
BS1 = fd.get_balance_sheet_annual(ticker)
BS = BS1[0].T[2:]
BS.columns = list(BS1[0].T.iloc[0])
BS
# Out:
#                                          2022-12-31   2021-12-31   2020-12-31  \
# totalAssets                             15456522000  10974118000  10450946000
# totalCurrentAssets                       5186917000   1993681000   2206184000
# cashAndCashEquivalentsAtCarryingValue    1499142000    439272000    746724000
# cashAndShortTermInvestments                 5890000    439272000     35000000
# inventory                                2076031000    798620000    750237000
# currentNetReceivables                    1590440000    735816000    683136000
# totalNonCurrentAssets                   11121233000   9214977000   8460334000
# propertyPlantEquipment                   6962997000   5909616000   5354625000
# accumulatedDepreciationAmortizationPPE   2391333000   2165130000   2073016000
# intangibleAssets                         1905497000   1906574000   2014625000
# intangibleAssetsExcludingGoodwill         287870000    308947000    349105000
# goodwill                                 1617627000   1597627000   1665520000
# investments                              1131793000    877048000    642108000
# longTermInvestments                      1150553000    912008000    656244000
# shortTermInvestments                        5890000    897708000        35000
# otherCurrentAssets                        234955000    132683000    116427000
# otherNonCurrentAssets                     250558000    252239000    219268000
# totalLiabilities                         7473895000   5348852000   6182719000
# totalCurrentLiabilities                  2741015000   1874335000   1801849000
# currentAccountsPayable                   1533624000    600487000    483221000
# deferredRevenue                                None         None         None
# currentDebt                                 7123000    393688000    806429000
# shortTermDebt                               2128000    389920000    804677000
# totalNonCurrentLiabilities               5169528000   3965086000   4837935000
# capitalLeaseObligations                    74409000     74011000     58543000
# longTermDebt                             3217100000   2394239000   3572058000
# currentLongTermDebt                         2128000    389920000    804677000
# longTermDebtNoncurrent                   3214972000   2004319000   2767381000
# shortLongTermDebtTotal                   3217100000   2394239000   3572058000
# otherCurrentLiabilities                   686886000    836429000    513951000
# otherNonCurrentLiabilities                636596000    663698000    629377000
# totalShareholderEquity                   7982627000   5625266000   4268227000
# treasuryStock                                  None         None         None
# retainedEarnings                         5601277000   3096539000   3155252000
# commonStock                                 1172000      1170000      1069000
# commonStockSharesOutstanding              117168000    117015000    106842000
#
#                                         2019-12-31  2018-12-31
# totalAssets                             9860863000  7581674000
# totalCurrentAssets                      2225109000  1998421000
# cashAndCashEquivalentsAtCarryingValue    613110000   555320000
# cashAndShortTermInvestments              613142000   555346000
# inventory                                768984000   700540000
# currentNetReceivables                    804507000   738367000
# totalNonCurrentAssets                   7829112000  5583253000
# propertyPlantEquipment                  4909473000  3021084000
# accumulatedDepreciationAmortizationPPE  1908370000  1777979000
# intangibleAssets                        1933407000  1953312000
# intangibleAssetsExcludingGoodwill        354622000   386143000
# goodwill                                1578785000  1567169000
# investments                              568099000   519571000
# longTermInvestments                      579813000   528722000
# shortTermInvestments                         32000       26000
# otherCurrentAssets                       162813000    84790000
# otherNonCurrentAssets                    213061000    80135000
# totalLiabilities                        5928613000  3996353000
# totalCurrentLiabilities                 1408996000  1183173000
# currentAccountsPayable                   574138000   522516000
# deferredRevenue                               None        None
# currentDebt                              211109000   307294000
# shortTermDebt                            210473000   307294000
# totalNonCurrentLiabilities              4622060000  2803243000
# capitalLeaseObligations                   58888000        None
# longTermDebt                            3050257000  1705210000
# currentLongTermDebt                      187336000   307294000
# longTermDebtNoncurrent                  2862921000  1397916000
# shortLongTermDebtTotal                  3050257000  1705210000
# otherCurrentLiabilities                  624385000   353363000
# otherNonCurrentLiabilities               754536000   526942000
# totalShareholderEquity                  3932250000  3585321000
# treasuryStock                                 None        None
# retainedEarnings                        2943478000  2566050000
# commonStock                                1061000     1056000
# commonStockSharesOutstanding             106040000   105616000

# %%
#CASHFLOW STATEMENT OF THE COMPANY
CS1 = fd.get_cash_flow_annual(ticker)
CS = CS1[0].T[2:]
CS.columns = list(CS1[0].T.iloc[0])
CS
# Out:
#                                                      2022-12-31  2021-12-31  \
# operatingCashflow                                    1907849000   344257000
# paymentsForOperatingActivities                        148213000    92840000
# proceedsFromOperatingActivities                        11564000    32677000
# changeInOperatingLiabilities                         1287072000   143939000
# changeInOperatingAssets                              2407079000   197785000
# depreciationDepletionAndAmortization                  300841000   254000000
# capitalExpenditures                                  1261646000   953667000
# changeInReceivables                                   786121000    49295000
# changeInInventory                                    1609642000   127401000
# profitLoss                                           2815131000   199942000
# cashflowFromInvestment                              -1422649000  -666590000
# cashflowFromFinancing                                 611887000    50212000
# proceedsFromRepaymentsOfShortTermDebt                      None        None
# paymentsForRepurchaseOfCommonStock                         None        None
# paymentsForRepurchaseOfEquity                              None        None
# paymentsForRepurchaseOfPreferredStock                      None        None
# dividendPayout                                        228637000   273989000
# dividendPayoutCommonStock                             184429000   177853000
# dividendPayoutPreferredStock                               None        None
# proceedsFromIssuanceOfCommonStock                             0  1453888000
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...   1964216000           0
# proceedsFromIssuanceOfPreferredStock                       None        None
# proceedsFromRepurchaseOfEquity                          2783000  1472280000
# proceedsFromSaleOfTreasuryStock                            None        None
# changeInCashAndCashEquivalents                       1097087000  -272121000
# changeInExchangeRate                                       None        None
# netIncome                                            2689816000   123672000
#
#                                                     2020-12-31   2019-12-31  \
# operatingCashflow                                    798914000    719374000
# paymentsForOperatingActivities                       120626000     92073000
# proceedsFromOperatingActivities                       25991000      7438000
# changeInOperatingLiabilities                         -31519000    -12234000
# changeInOperatingAssets                             -158022000     83071000
# depreciationDepletionAndAmortization                 231984000    213484000
# capitalExpenditures                                  850477000    851796000
# changeInReceivables                                 -100118000     18220000
# changeInInventory                                    -51978000     46304000
# profitLoss                                           446615000    604357000
# cashflowFromInvestment                              -863573000  -1663625000
# cashflowFromFinancing                                177261000   1042687000
# proceedsFromRepaymentsOfShortTermDebt                     None         None
# paymentsForRepurchaseOfCommonStock                           0            0
# paymentsForRepurchaseOfEquity                                0            0
# paymentsForRepurchaseOfPreferredStock                     None         None
# dividendPayout                                       193879000    235391000
# dividendPayoutCommonStock                            161818000    152204000
# dividendPayoutPreferredStock                              None         None
# proceedsFromIssuanceOfCommonStock                            0            0
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...   452163000   1597807000
# proceedsFromIssuanceOfPreferredStock                      None         None
# proceedsFromRepurchaseOfEquity                        40437000      4814000
# proceedsFromSaleOfTreasuryStock                           None         None
# changeInCashAndCashEquivalents                       112602000     57790000
# changeInExchangeRate                                      None    -40646000
# netIncome                                            375764000    533228000
#
#                                                     2018-12-31
# operatingCashflow                                    546165000
# paymentsForOperatingActivities                        64998000
# proceedsFromOperatingActivities                       21459000
# changeInOperatingLiabilities                          73730000
# changeInOperatingAssets                              174532000
# depreciationDepletionAndAmortization                 200698000
# capitalExpenditures                                  699991000
# changeInReceivables                                   97448000
# changeInInventory                                    124067000
# profitLoss                                           739139000
# cashflowFromInvestment                              -303695000
# cashflowFromFinancing                               -786526000
# proceedsFromRepaymentsOfShortTermDebt                     None
# paymentsForRepurchaseOfCommonStock                   500000000
# paymentsForRepurchaseOfEquity                        500000000
# paymentsForRepurchaseOfPreferredStock                     None
# dividendPayout                                       159352000
# dividendPayoutCommonStock                            144596000
# dividendPayoutPreferredStock                              None
# proceedsFromIssuanceOfCommonStock                         None
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...           0
# proceedsFromIssuanceOfPreferredStock                      None
# proceedsFromRepurchaseOfEquity                      -496367000
# proceedsFromSaleOfTreasuryStock                           None
# changeInCashAndCashEquivalents                      -581983000
# changeInExchangeRate                                 -37927000
# netIncome                                            693562000

# %%
#DEF FUNCTONS FOR THE DELTA FACTORS

def net_income():
    df=IS
    return float(df.loc['netIncome'][0])

def ROA():
    df=BS
    p,q= float(df.loc['totalAssets'][0]), float(df.loc['totalAssets'][1])
    av_assets=(p+q)/2
    return net_income()/av_assets

def OCF():
    df=CS
    return float(df.loc['operatingCashflow'][0])

def LTdebt():
    df=BS
    p,q=float(df.loc['longTermDebt'][0]),float(df.loc['longTermDebt'][1])
    return q-p

def current_ratio():
    df=BS
    p,q=float(df.loc['totalCurrentAssets'][0]),float(df.loc['totalCurrentAssets'][1])
    r,s=float(df.loc['totalCurrentLiabilities'][0]),float(df.loc['totalCurrentLiabilities'][1])
    current_ratio1,current_ratio2=p/r,q/s
    return current_ratio1-current_ratio2

def new_shares():
    return float(BS.loc['commonStock'][0]) - float(BS.loc['commonStock'][1])

def gross_margin():
    df=IS
    gross_margin_this = float(IS.loc['grossProfit'][0])/float(IS.loc['totalRevenue'][0])
    gross_margin_last = float(IS.loc['grossProfit'][1])/float(IS.loc['totalRevenue'][1])
    return gross_margin_this - gross_margin_last

def Asset_Turnover_Ratio():
    df1=IS
    df2=BS
    p,q,s=float(df2.loc['totalAssets'][0]),float(df2.loc['totalAssets'][1]),float(df2.loc['totalAssets'][2])
    av_assets1=(p+q)/2
    av_assets2=(q+s)/2
    atr1=float(df1.loc['totalRevenue'][0])/av_assets1
    atr2=float(df1.loc['totalRevenue'][1])/av_assets2
    return atr1-atr2

# %%
#F-SCORE CALCULATION

def Pietroski_Score():
    Pscore=0
    if net_income()>0:
        Pscore+=1
    if ROA()>0:
        Pscore+=1
    if OCF()>0:
        Pscore+=1
    if LTdebt()>0:
        Pscore+=1
    if current_ratio()>0:
        Pscore+=1
    if new_shares()>0:
        Pscore+=1
    if gross_margin()>0:
        Pscore+=1
    if Asset_Turnover_Ratio()>0:
        Pscore+=1
    return Pscore

Pietroski_Score()
# Out:
# 7
